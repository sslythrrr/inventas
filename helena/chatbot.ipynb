# %%
from flask import Flask, request, jsonify
from flask_cors import CORS
import torch
import json
import logging
from datetime import datetime
import threading
from transformers import BertTokenizer, BertForSequenceClassification, BertForTokenClassification, AutoTokenizer
from sentence_transformers import SentenceTransformer, util
import numpy as np

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

app = Flask(__name__)
CORS(app)

intent_model = None
ner_model = None
tokenizer = None
tokenizer_ner = None
intent_labels = []
intent_data = None
label2id = None
id2label = None
semantic_model = None

def load_intent(file_path):
    intent_data = {'intents': []}
    intent_dict = {}

    with open(file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    for line in lines:
        line = line.strip()
        if line:
            parts = line.rsplit(' ', 1)
            if len(parts) == 2:
                pattern, tag = parts
                if tag not in intent_dict:
                    intent_dict[tag] = {'tag': tag, 'patterns': [], 'responses': [f"{tag}"]}
                intent_dict[tag]['patterns'].append(pattern)

    intent_data['intents'] = list(intent_dict.values())
    return intent_data

def initialize_models():
    """Initialize models"""
    global intent_model, ner_model, tokenizer, tokenizer_ner, intent_labels, intent_data, label2id, id2label, semantic_model

    try:
        logger.info("Initializing models...")

        intent_data = load_intent('intent.txt')

        intent_labels = [intent['tag'] for intent in intent_data['intents']]
        logger.info(f"Loaded {len(intent_labels)} intent labels")

        try:
            with open('ner_label_mapping.json', 'r', encoding='utf-8') as f:
                ner_mapping = json.load(f)
                label2id = ner_mapping['label2id']
                id2label = {int(k): v for k, v in ner_mapping['id2label'].items()}
            logger.info("NER label mapping loaded")
        except FileNotFoundError:
            logger.warning("NER label mapping file not found")
            label2id = None
            id2label = None

        tokenizer = BertTokenizer.from_pretrained('./models/indobert-base-p2')
        tokenizer_ner = AutoTokenizer.from_pretrained('./models/indobert-base-p2')

        intent_model = BertForSequenceClassification.from_pretrained(
            './models/indobert-base-p2',
            num_labels=len(intent_labels)
        )
        intent_model.load_state_dict(torch.load('intent_model.pth', map_location='cpu'))
        intent_model.eval()

        if label2id:
            ner_model = BertForTokenClassification.from_pretrained(
                './models/indobert-base-p2',
                num_labels=len(label2id),
                id2label=id2label,
                label2id=label2id
            )
            ner_model.load_state_dict(torch.load('ner_model.pth', map_location='cpu'))
            ner_model.eval()
            logger.info("NER model loaded")
        else:
            ner_model = None
            
        # Semantic similarity model
        logger.info("Loading semantic similarity model...")
        semantic_model = SentenceTransformer('./models/indobert-base-p2-sts-arxiv-id')
        semantic_model.eval()
        logger.info("Semantic model loaded")

        logger.info("All models loaded successfully")
        return True

    except Exception as e:
        logger.error(f"Failed to load models: {str(e)}")
        return False

def predict_intent(text):
    try:
        encoding = tokenizer(text, truncation=True, padding='max_length', max_length=128, return_tensors='pt')
        with torch.no_grad():
            outputs = intent_model(**encoding)
            probs = torch.softmax(outputs.logits, dim=-1)
            max_prob = torch.max(probs).item()
            pred = torch.argmax(outputs.logits, dim=1)
            predicted_intent = intent_labels[pred.item()]

            if max_prob < 0.8:
                return 'fallback', max_prob  
            else:
                return predicted_intent, max_prob  
    except Exception as e:
        logger.error(f"Intent prediction error: {str(e)}")
        return "fallback", 0.0  

def predict_ner(text):
    """Predict NER"""
    if not ner_model:
        return []

    try:
        tokens = text.split()
        encoding = tokenizer_ner(tokens, is_split_into_words=True, return_tensors='pt', truncation=True, padding='max_length', max_length=128)
        with torch.no_grad():
            outputs = ner_model(**encoding)
            logits = outputs.logits
            preds = torch.argmax(logits, dim=-1).cpu().numpy()[0]

        word_ids = encoding.word_ids(batch_index=0)
        result = []
        seen_word_idx = set()
        for idx, word_idx in enumerate(word_ids):
            if word_idx is not None and word_idx not in seen_word_idx and word_idx < len(tokens):
                label = id2label[preds[idx]]
                result.append((tokens[word_idx], label))
                seen_word_idx.add(word_idx)
        return result
    except Exception as e:
        logger.error(f"NER prediction error: {str(e)}")
        return []

def extract_entities(ner_result):
    """Extract structured entities"""
    entities = {}
    current_entity = None
    current_tokens = []
    prev_token = None

    for token, label in ner_result:
        if token == prev_token and label.startswith("I-"):
            continue

        if label.startswith('B-'):
            if current_entity and current_tokens:
                ent_type = current_entity[2:]
                entities.setdefault(ent_type, []).append(' '.join(current_tokens))
            current_entity = label
            current_tokens = [token]
        elif label.startswith('I-'):
            if current_entity and current_entity[2:] == label[2:]:
                current_tokens.append(token)
            else:
                if current_entity and current_tokens:
                    ent_type = current_entity[2:]
                    entities.setdefault(ent_type, []).append(' '.join(current_tokens))
                current_entity = 'B-' + label[2:]
                current_tokens = [token]
        else:
            if current_entity and current_tokens:
                ent_type = current_entity[2:]
                entities.setdefault(ent_type, []).append(' '.join(current_tokens))
            current_entity = None
            current_tokens = []

        prev_token = token

    # Handle last entity
    if current_entity and current_tokens:
        ent_type = current_entity[2:]
        entities.setdefault(ent_type, []).append(' '.join(current_tokens))

    return entities

def generate_response(intent, entities=None):
    """Generate response"""
    try:
        for item in intent_data['intents']:
            if item['tag'] == intent:
                response = item['responses'][0]
                if entities:
                    for key, values in entities.items():
                        value = values[0] if isinstance(values, list) else values
                        response = response.replace(f'{{{key}}}', value)
                return response
        return "Maaf, saya tidak mengerti pertanyaan Anda."
    except Exception as e:
        logger.error(f"Error generating response: {str(e)}")
        return "Maaf, terjadi kesalahan."

@app.route('/health', methods=['GET'])
def health():
    return jsonify({
        'status': 'OK',
        'message': 'Chatbot API is running',
        'timestamp': datetime.now().isoformat(),
        'models_loaded': {
            'intent': intent_model is not None,
            'ner': ner_model is not None
        }
    })

@app.route('/predict', methods=['POST'])
def predict():
    try:
        if not request.is_json:
            return jsonify({'error': 'Request must be JSON', 'status': 'error'}), 400
        data = request.get_json()
        text = data.get('text', '').strip()

        if not text:
            return jsonify({'error': 'Text cannot be empty', 'status': 'error'}), 400

        logger.info(f"Input text: {text}")

        intent, confidence = predict_intent(text)
        logger.info(f"Predicted intent: {intent}")

        ner_result = predict_ner(text)
        logger.info(f"Raw NER: {ner_result}")

        entities = extract_entities(ner_result)
        logger.info(f"Extracted entities: {entities}")

        response = generate_response(intent, entities)

        result = {
            'intent': intent,
            'confidence': confidence,  
            'entities': entities,
            'ner_tokens': ner_result,
            'response': response,
            'status': 'success',
            'timestamp': datetime.now().isoformat()
        }
        return jsonify(result)

    except Exception as e:
        logger.error(f"Server error: {str(e)}")
        return jsonify({'error': 'Internal server error', 'details': str(e), 'status': 'error'}), 500

@app.route('/semantic-search', methods=['POST'])
def semantic_search():
    try:
        if not request.is_json:
            return jsonify({'error': 'Request must be JSON'}), 400
        
        data = request.get_json()
        query = data.get('query', '').strip()
        items = data.get('items', [])
        threshold = data.get('threshold', 0.5)
        top_k = data.get('top_k', 5)
        
        if not query or not items:
            return jsonify({'error': 'Query and items required'}), 400
        
        # Check semantic model availability
        if semantic_model is None:
            logger.error("Semantic model not loaded")
            return jsonify({'error': 'Semantic model not initialized'}), 500
        
        logger.info(f"Semantic search for: {query} among {len(items)} items")
        
        # Encode query and items
        query_emb = semantic_model.encode(query, convert_to_tensor=True, normalize_embeddings=True)
        item_embeddings = semantic_model.encode(items, convert_to_tensor=True, normalize_embeddings=True)
        
        cosine_scores = util.cos_sim(query_emb, item_embeddings)[0]
        
        # Sort and filter results
        all_scores = [(i, float(score)) for i, score in enumerate(cosine_scores)]
        all_scores.sort(key=lambda x: x[1], reverse=True)
        
        results = []
        for idx, score in all_scores[:top_k]:
            if score >= threshold:
                results.append({
                    'nama': items[idx],
                    'score': score
                })
        
        logger.info(f"Found {len(results)} semantic matches above {threshold}")
        return jsonify({
            'status': 'success',
            'results': results,
            'query': query
        })
        
    except Exception as e:
        logger.error(f"Semantic search error: {str(e)}", exc_info=True)
        return jsonify({'error': str(e), 'status': 'error'}), 500

@app.route('/test', methods=['GET'])
def test():
    return jsonify({'message': 'API is working!', 'timestamp': datetime.now().isoformat()})


if __name__ == '__main__':
    if initialize_models():
        app.run(host='0.0.0.0', port=5000)
    else:
        logger.error("Server not started due to model loading failure")
# Out:
# INFO:__main__:Initializing models...
# INFO:__main__:Loaded 9 intent labels
# INFO:__main__:NER label mapping loaded
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at ./models/indobert-base-p2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at ./models/indobert-base-p2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:__main__:NER model loaded
# INFO:__main__:Loading semantic similarity model...
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cpu
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: ./models/indobert-base-p2-sts-arxiv-id
# INFO:__main__:Semantic model loaded
# INFO:__main__:All models loaded successfully
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.43.223:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:__main__:Input text: ada berapa unit kursi
# INFO:__main__:Predicted intent: jumlah_barang
# INFO:__main__:Raw NER: [('ada', 'O'), ('berapa', 'B-quantity'), ('unit', 'O'), ('kursi', 'B-item')]
# INFO:__main__:Extracted entities: {'quantity': ['berapa'], 'item': ['kursi']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 09:41:38] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: kulkas
# INFO:__main__:Predicted intent: fallback
# INFO:__main__:Raw NER: [('kulkas', 'B-item')]
# INFO:__main__:Extracted entities: {'item': ['kulkas']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 09:41:55] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: dimana lokasi krusi
# INFO:__main__:Predicted intent: lokasi_barang
# INFO:__main__:Raw NER: [('dimana', 'O'), ('lokasi', 'B-location'), ('krusi', 'O')]
# INFO:__main__:Extracted entities: {'location': ['lokasi']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 09:43:23] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: dimana lokasi kulkas
# INFO:__main__:Predicted intent: lokasi_barang
# INFO:__main__:Raw NER: [('dimana', 'O'), ('lokasi', 'B-location'), ('kulkas', 'B-item')]
# INFO:__main__:Extracted entities: {'location': ['lokasi'], 'item': ['kulkas']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 09:45:01] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Semantic search for: kulkas among 43 items
# Batches: 100%|██████████| 1/1 [00:01<00:00,  1.59s/it]
# Batches: 100%|██████████| 2/2 [00:02<00:00,  1.43s/it]
# INFO:__main__:Found 5 semantic matches above 0.2
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 09:45:05] "POST /semantic-search HTTP/1.1" 200 -
# INFO:__main__:Input text: kursi
# INFO:__main__:Predicted intent: fallback
# INFO:__main__:Raw NER: [('kursi', 'B-item')]
# INFO:__main__:Extracted entities: {'item': ['kursi']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:01:23] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: tempat duduk
# INFO:__main__:Predicted intent: lokasi_barang
# INFO:__main__:Raw NER: [('tempat', 'B-location'), ('duduk', 'O')]
# INFO:__main__:Extracted entities: {'location': ['tempat']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:01:33] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: mesin cetak
# INFO:__main__:Predicted intent: fallback
# INFO:__main__:Raw NER: [('mesin', 'B-item'), ('cetak', 'I-item')]
# INFO:__main__:Extracted entities: {'item': ['mesin cetak']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:01:49] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Semantic search for: mesin cetak among 43 items
# Batches: 100%|██████████| 1/1 [00:00<00:00,  7.73it/s]
# Batches: 100%|██████████| 2/2 [00:02<00:00,  1.38s/it]
# INFO:__main__:Found 5 semantic matches above 0.2
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:01:52] "POST /semantic-search HTTP/1.1" 200 -
# INFO:__main__:Input text: meja
# INFO:__main__:Predicted intent: lokasi_barang
# INFO:__main__:Raw NER: [('meja', 'B-item')]
# INFO:__main__:Extracted entities: {'item': ['meja']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:02:28] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: berapa harga kursi
# INFO:__main__:Predicted intent: harga_barang
# INFO:__main__:Raw NER: [('berapa', 'O'), ('harga', 'B-price'), ('kursi', 'I-item')]
# INFO:__main__:Extracted entities: {'price': ['harga'], 'item': ['kursi']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:02:38] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: apa status rka
# INFO:__main__:Predicted intent: status_barang
# INFO:__main__:Raw NER: [('apa', 'O'), ('status', 'B-status'), ('rka', 'B-status')]
# INFO:__main__:Extracted entities: {'status': ['status', 'rka']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:02:46] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: apa status rak
# INFO:__main__:Predicted intent: status_barang
# INFO:__main__:Raw NER: [('apa', 'O'), ('status', 'B-status'), ('rak', 'B-status')]
# INFO:__main__:Extracted entities: {'status': ['status', 'rak']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:02:51] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: apa status lemaro
# INFO:__main__:Predicted intent: status_barang
# INFO:__main__:Raw NER: [('apa', 'O'), ('status', 'B-status'), ('lemaro', 'B-item')]
# INFO:__main__:Extracted entities: {'status': ['status'], 'item': ['lemaro']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:02:57] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: lemaro
# INFO:__main__:Predicted intent: fallback
# INFO:__main__:Raw NER: [('lemaro', 'B-item')]
# INFO:__main__:Extracted entities: {'item': ['lemaro']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:03:03] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: sofi
# INFO:__main__:Predicted intent: fallback
# INFO:__main__:Raw NER: [('sofi', 'B-sapaan')]
# INFO:__main__:Extracted entities: {'sapaan': ['sofi']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:03:06] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Semantic search for: sofi among 43 items
# Batches: 100%|██████████| 1/1 [00:00<00:00,  7.28it/s]
# Batches: 100%|██████████| 2/2 [00:03<00:00,  1.65s/it]
# INFO:__main__:Found 5 semantic matches above 0.2
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:03:09] "POST /semantic-search HTTP/1.1" 200 -
# INFO:__main__:Input text: comptuer
# INFO:__main__:Predicted intent: fallback
# INFO:__main__:Raw NER: [('comptuer', 'B-item')]
# INFO:__main__:Extracted entities: {'item': ['comptuer']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:03:46] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: kursi
# INFO:__main__:Predicted intent: fallback
# INFO:__main__:Raw NER: [('kursi', 'B-item')]
# INFO:__main__:Extracted entities: {'item': ['kursi']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:04:47] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: barang apa yang dilelang
# INFO:__main__:Predicted intent: lelang_barang
# INFO:__main__:Raw NER: [('barang', 'B-item'), ('apa', 'O'), ('yang', 'O'), ('dilelang', 'B-status')]
# INFO:__main__:Extracted entities: {'item': ['barang'], 'status': ['dilelang']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:20:20] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: barang apa yang akan lelang
# INFO:__main__:Predicted intent: lelang_barang
# INFO:__main__:Raw NER: [('barang', 'B-item'), ('apa', 'O'), ('yang', 'O'), ('akan', 'O'), ('lelang', 'B-status')]
# INFO:__main__:Extracted entities: {'item': ['barang'], 'status': ['lelang']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:20:26] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: berapa harga mesin cetak
# INFO:__main__:Predicted intent: harga_barang
# INFO:__main__:Raw NER: [('berapa', 'O'), ('harga', 'B-price'), ('mesin', 'I-item'), ('cetak', 'I-item')]
# INFO:__main__:Extracted entities: {'price': ['harga'], 'item': ['mesin cetak']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:21:57] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Semantic search for: mesin cetak among 43 items
# Batches: 100%|██████████| 1/1 [00:00<00:00,  7.21it/s]
# Batches: 100%|██████████| 2/2 [00:02<00:00,  1.40s/it]
# INFO:__main__:Found 5 semantic matches above 0.2
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:22:00] "POST /semantic-search HTTP/1.1" 200 -
# INFO:__main__:Input text: berapa harga komputer
# INFO:__main__:Predicted intent: harga_barang
# INFO:__main__:Raw NER: [('berapa', 'O'), ('harga', 'B-price'), ('komputer', 'I-item')]
# INFO:__main__:Extracted entities: {'price': ['harga'], 'item': ['komputer']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:22:06] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: status meja apa
# INFO:__main__:Predicted intent: status_barang
# INFO:__main__:Raw NER: [('status', 'B-status'), ('meja', 'B-item'), ('apa', 'O')]
# INFO:__main__:Extracted entities: {'status': ['status'], 'item': ['meja']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:22:35] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: berapa banyak barang di ruang rapat
# INFO:__main__:Predicted intent: jumlah_barang
# INFO:__main__:Raw NER: [('berapa', 'O'), ('banyak', 'O'), ('barang', 'B-item'), ('di', 'O'), ('ruang', 'B-location'), ('rapat', 'I-item')]
# INFO:__main__:Extracted entities: {'item': ['barang', 'rapat'], 'location': ['ruang']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:23:20] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Semantic search for: barang among 43 items
# Batches: 100%|██████████| 1/1 [00:00<00:00,  9.68it/s]
# Batches: 100%|██████████| 2/2 [00:02<00:00,  1.45s/it]
# INFO:__main__:Found 5 semantic matches above 0.2
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:23:23] "POST /semantic-search HTTP/1.1" 200 -
# INFO:__main__:Input text: halo
# INFO:__main__:Predicted intent: sapaan
# INFO:__main__:Raw NER: [('halo', 'O')]
# INFO:__main__:Extracted entities: {}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:25:52] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: Berapa harga laptop
# INFO:__main__:Predicted intent: harga_barang
# INFO:__main__:Raw NER: [('Berapa', 'O'), ('harga', 'B-price'), ('laptop', 'I-item')]
# INFO:__main__:Extracted entities: {'price': ['harga'], 'item': ['laptop']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:26:40] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Semantic search for: laptop among 43 items
# Batches: 100%|██████████| 1/1 [00:00<00:00, 10.25it/s]
# Batches: 100%|██████████| 2/2 [00:02<00:00,  1.38s/it]
# INFO:__main__:Found 5 semantic matches above 0.2
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:26:43] "POST /semantic-search HTTP/1.1" 200 -
# INFO:__main__:Input text: Berapa harga kursi
# INFO:__main__:Predicted intent: harga_barang
# INFO:__main__:Raw NER: [('Berapa', 'O'), ('harga', 'B-price'), ('kursi', 'I-item')]
# INFO:__main__:Extracted entities: {'price': ['harga'], 'item': ['kursi']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:27:02] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: harga ksui berapa
# INFO:__main__:Predicted intent: harga_barang
# INFO:__main__:Raw NER: [('harga', 'B-price'), ('ksui', 'I-item'), ('berapa', 'O')]
# INFO:__main__:Extracted entities: {'price': ['harga'], 'item': ['ksui']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:27:23] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Semantic search for: ksui among 43 items
# Batches: 100%|██████████| 1/1 [00:00<00:00,  8.47it/s]
# Batches: 100%|██████████| 2/2 [00:02<00:00,  1.34s/it]
# INFO:__main__:Found 3 semantic matches above 0.2
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:27:26] "POST /semantic-search HTTP/1.1" 200 -
# INFO:__main__:Input text: mesin cetak
# INFO:__main__:Predicted intent: fallback
# INFO:__main__:Raw NER: [('mesin', 'B-item'), ('cetak', 'I-item')]
# INFO:__main__:Extracted entities: {'item': ['mesin cetak']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:27:49] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Semantic search for: mesin cetak among 43 items
# Batches: 100%|██████████| 1/1 [00:00<00:00,  7.91it/s]
# Batches: 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
# INFO:__main__:Found 5 semantic matches above 0.2
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:27:52] "POST /semantic-search HTTP/1.1" 200 -
# INFO:__main__:Input text: berapa harga krusi
# INFO:__main__:Predicted intent: harga_barang
# INFO:__main__:Raw NER: [('berapa', 'O'), ('harga', 'B-price'), ('krusi', 'I-item')]
# INFO:__main__:Extracted entities: {'price': ['harga'], 'item': ['krusi']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:28:11] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: Ada berapa krusi
# INFO:__main__:Predicted intent: jumlah_barang
# INFO:__main__:Raw NER: [('Ada', 'O'), ('berapa', 'B-quantity'), ('krusi', 'B-item')]
# INFO:__main__:Extracted entities: {'quantity': ['berapa'], 'item': ['krusi']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:28:37] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: ada berapa kursi
# INFO:__main__:Predicted intent: jumlah_barang
# INFO:__main__:Raw NER: [('ada', 'O'), ('berapa', 'B-quantity'), ('kursi', 'B-item')]
# INFO:__main__:Extracted entities: {'quantity': ['berapa'], 'item': ['kursi']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:28:43] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: barang apa yang sedang dilelang
# INFO:__main__:Predicted intent: lelang_barang
# INFO:__main__:Raw NER: [('barang', 'B-item'), ('apa', 'O'), ('yang', 'O'), ('sedang', 'O'), ('dilelang', 'B-status')]
# INFO:__main__:Extracted entities: {'item': ['barang'], 'status': ['dilelang']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:29:56] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: barang apa yang sedang dilelang
# INFO:__main__:Predicted intent: lelang_barang
# INFO:__main__:Raw NER: [('barang', 'B-item'), ('apa', 'O'), ('yang', 'O'), ('sedang', 'O'), ('dilelang', 'B-status')]
# INFO:__main__:Extracted entities: {'item': ['barang'], 'status': ['dilelang']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:30:35] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: panduang sistem
# INFO:__main__:Predicted intent: fallback
# INFO:__main__:Raw NER: [('panduang', 'O'), ('sistem', 'O')]
# INFO:__main__:Extracted entities: {}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:30:38] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Semantic search for: panduang sistem among 43 items
# Batches: 100%|██████████| 1/1 [00:00<00:00,  6.13it/s]
# Batches: 100%|██████████| 2/2 [00:02<00:00,  1.41s/it]
# INFO:__main__:Found 1 semantic matches above 0.2
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:30:41] "POST /semantic-search HTTP/1.1" 200 -
# INFO:__main__:Input text: seblak
# INFO:__main__:Predicted intent: fallback
# INFO:__main__:Raw NER: [('seblak', 'B-sapaan')]
# INFO:__main__:Extracted entities: {'sapaan': ['seblak']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:30:54] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Semantic search for: seblak among 43 items
# Batches: 100%|██████████| 1/1 [00:00<00:00,  8.07it/s]
# Batches: 100%|██████████| 2/2 [00:02<00:00,  1.43s/it]
# INFO:__main__:Found 5 semantic matches above 0.2
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 10:30:57] "POST /semantic-search HTTP/1.1" 200 -
# INFO:__main__:Input text: ada berapa unit kursi
# INFO:__main__:Predicted intent: jumlah_barang
# INFO:__main__:Raw NER: [('ada', 'O'), ('berapa', 'B-quantity'), ('unit', 'O'), ('kursi', 'B-item')]
# INFO:__main__:Extracted entities: {'quantity': ['berapa'], 'item': ['kursi']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 11:50:16] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: tempat duduk
# INFO:__main__:Predicted intent: lokasi_barang
# INFO:__main__:Raw NER: [('tempat', 'B-location'), ('duduk', 'O')]
# INFO:__main__:Extracted entities: {'location': ['tempat']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 12:06:41] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Input text: Ada berapa tempat duudk
# INFO:__main__:Predicted intent: fallback
# INFO:__main__:Raw NER: [('Ada', 'O'), ('berapa', 'B-quantity'), ('tempat', 'O'), ('duudk', 'O')]
# INFO:__main__:Extracted entities: {'quantity': ['berapa']}
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 12:06:50] "POST /predict HTTP/1.1" 200 -
# INFO:__main__:Semantic search for: Ada berapa tempat duudk among 43 items
# Batches: 100%|██████████| 1/1 [00:01<00:00,  1.03s/it]
# Batches: 100%|██████████| 2/2 [00:02<00:00,  1.46s/it]
# INFO:__main__:Found 5 semantic matches above 0.2
# INFO:werkzeug:127.0.0.1 - - [14/Oct/2025 12:06:54] "POST /semantic-search HTTP/1.1" 200 -
